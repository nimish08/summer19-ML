# %% [markdown]
# <a href="https://colab.research.google.com/github/nimish08/summer19-ML/blob/master/API_tweepy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy

# %%
api=tweepy.API(auth)

# %%
consumerkey=''
consumersecret=''
accessToken=''
accessTokenSecret=''

auth=tweepy.OAuthHandler(consumer_key=consumerkey,consumer_secret=consumersecret)
auth.set_access_token(accessToken,accessTokenSecret)

# %%
search=input("Enter word to be searched")
numberwords=int(input("number of words"))
# Out:
# Enter word to be searchedstranger things
# number of words50

# %%
result=api.search(search,count=numberwords)
result
# Out:
# [Status(_api=<tweepy.api.API object at 0x7f1f7a82c160>, _json={'created_at': 'Fri Jul 05 09:30:35 +0000 2019', 'id': 1147075291811946496, 'id_str': '1147075291811946496', 'text': 'Loving the vibe from stranger things season 3. Neon lights I wanna Buy all the neon lights I can and hang em up in my living room haha', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1146226270675468288, 'id_str': '1146226270675468288', 'name': 'Dr_EternalCowboy', 'screen_name': 'MrSaiyajiin', 'location': '', 'description': 'Video games | Wrestling | Cars | Music | Vape | Paranormal | Beer | Baseball | My interests', 'url': 
# ...

# %%
for i in result:
  print(i.text)
# Out:
# Loving the vibe from stranger things season 3. Neon lights I wanna Buy all the neon lights I can and hang em up in my living room haha
# stranger things 3 ending https://t.co/tAER2wy5GY
# Me veo stranger things solo con mis padres o les traicionó y me la veo sola de una tandada y me la vuelvo a ver con… https://t.co/NnclsQsk7X
# RT @drawoHkciN38: Suzie was the other villain in Stranger Things. How are you gonna know the world is in danger and force Dustin to sing a…
# RT @Aracnephobia: En mi vida, soy como Will en Stranger Things. Mientras todos sufren sus devenires diarios, no paro de preguntar SI PODEMO…
# Stranger things is very boring
# RT @egavactip: I was just sitting there watching Stranger Things when my Ph.D. in military history flew off the wall, stormed down the hall…
# Stranger things coisa linda
# i wanna watch stranger things but how season two treated its lady leads left a bad taste tbqh
# thinking about letting the stranger things hype die first before watching it
# ...
